# %%
# autorelead libraries
# %load_ext autoreload
# %autoreload 2

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

print("CUDA_VISIBLE_DEVICES:", os.environ.get("CUDA_VISIBLE_DEVICES"))
print("torch sees:", torch.cuda.device_count(), "GPUs")
print("Current device index:", torch.cuda.current_device())
print("Device name:", torch.cuda.get_device_name())
# Out:
# Using: cuda
# CUDA_VISIBLE_DEVICES: 1
# torch sees: 1 GPUs
# Current device index: 0
# Device name: NVIDIA GeForce RTX 2080 Ti

# %%
import os
import time
import random
import pickle
import argparse
import heartpy as hp
from heartpy.datautils import rolling_mean
import numpy as np
import scipy.sparse as sp
import scipy.signal as sig
import scipy.stats as stats
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
from torch.utils.data import DataLoader

from config import get_config
from dataset import data_loader
from neural_methods.model.ContrastPhys import ContrastPhys
from neural_methods.model.PhysNet import PhysNet_padding_Encoder_Decoder_MAX
from neural_methods.model.FactorizePhys.FactorizePhys import FactorizePhys
from neural_methods.model.FactorizePhys.FactorizePhysBig import FactorizePhysBig
from neural_methods.model.PhysMamba import PhysMamba
from neural_methods.model.ContrastFusion import ContrastFusion
from neural_methods.model.PhysFormer import ViT_ST_ST_Compact3_TDC_gra_sharp
from neural_methods.model.RhythmFormer import RhythmFormer
from neural_methods.model.WaveformFusion import WaveformFusion
# Out:
# 2025-07-29 16:28:23.206183: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-29 16:28:23.220359: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753824503.237500  423015 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753824503.242725  423015 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753824503.255940  423015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753824503.255967  423015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753824503.255969  423015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753824503.255970  423015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-29 16:28:23.260753: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def calcMetrics(input_data, sampFreq, B, window_size=None, use_harmonic=False, normalize=False):
    # define goodness parameters
    B1 = 0.75 # low cutoff
    B2 = 3 # high cutoff

    if window_size is None:
        pulseCalcLength = len(input_data)
    else:
        pulseCalcLength = np.uint32(window_size/(1.0/sampFreq))
    pulseRate_result = np.empty(len(input_data)-pulseCalcLength + 1)
    goodnessMetric_result = np.empty(len(input_data)-pulseCalcLength + 1)

    for i in range(0, len(pulseRate_result)):
        window = input_data[i:i+pulseCalcLength]
        # sigFreq, sigPower = sig.periodogram(window, fs=sampFreq, nfft=180000)
        sigFreq, sigPower = sig.welch(x=window, nperseg=len(window)//3, fs=sampFreq, nfft=180000)
        maskFreq = (sigFreq > B1)&(sigFreq<B2)
        # sigFreq = sigFreq[maskFreq]
        sigPower = sigPower * maskFreq
        if use_harmonic:
            # harmonic PSD
            harmonicsigPower = sigPower[::2]
            harmonicsigPower = np.pad(harmonicsigPower, (0, len(sigPower) - len(harmonicsigPower)))
            # find peak frequency
            peakFreq = sigFreq[np.argmax(sigPower + harmonicsigPower)]
        else:
            peakFreq = sigFreq[np.argmax(sigPower)]
        pulseRate = 60.0*peakFreq
        pulseRate_result[i] = pulseRate
        # compute goodness
        aroundPulseRate = (sigFreq > peakFreq - B) & (sigFreq < peakFreq + B)
        withinBandpass = (sigFreq >= B1) & (sigFreq <= B2)
        powerPulseRate = np.sum(sigPower[aroundPulseRate])
        powerAll = np.sum(sigPower[withinBandpass])
        if normalize:
            goodnessMetric_result[i] = powerPulseRate / powerAll
        else:
            goodnessMetric_result[i] = powerPulseRate / (powerAll - powerPulseRate)
    timestamps = np.arange(len(pulseRate_result))
    return timestamps, goodnessMetric_result, pulseRate_result

def custom_detrend(sig, Lambda):
    """custom_detrend(sig, Lambda) -> filtered_signal
    This function applies a detrending filter.
    This code is based on the following article "An advanced detrending method with application
    to HRV analysis". Tarvainen et al., IEEE Trans on Biomedical Engineering, 2002.
    *Parameters*
      ``sig`` (1d numpy array):
        The sig where you want to remove the trend.
      ``Lambda`` (int):
        The smoothing parameter.
    *Returns*
      ``filtered_signal`` (1d numpy array):
        The detrended sig.
    """
    signal_length = sig.shape[0]

    # observation matrix
    H = np.identity(signal_length)

    # second-order difference matrix

    ones = np.ones(signal_length)
    minus_twos = -2 * np.ones(signal_length)
    diags_data = np.array([ones, minus_twos, ones])
    diags_index = np.array([0, 1, 2])
    D = sp.spdiags(diags_data, diags_index, (signal_length - 2), signal_length).toarray()
    filtered_signal = np.dot((H - np.linalg.inv(H + (Lambda ** 2) * np.dot(D.T, D))), sig)
    return filtered_signal

def pulse_rate_from_power_spectral_density(pleth_sig: np.array, FS: float,
                                           LL_PR: float, UL_PR: float,
                                           BUTTER_ORDER: int = 6,
                                           DETREND: bool = False,
                                           FResBPM: float = 0.1,
                                           HARMONIC: bool = False,
                                           WELCH = True) -> float:
    """ Function to estimate the pulse rate from the power spectral density of the plethysmography sig.

    Args:
        pleth_sig (np.array): Plethysmography sig.
        FS (float): Sampling frequency.
        LL_PR (float): Lower cutoff frequency for the butterworth filtering.
        UL_PR (float): Upper cutoff frequency for the butterworth filtering.
        BUTTER_ORDER (int, optional): Order of the butterworth filter. Give None to skip filtering. Defaults to 6.
        DETREND (bool, optional): Boolena Flag for executing cutsom_detrend. Defaults to False.
        FResBPM (float, optional): Frequency resolution. Defaults to 0.1.

    Returns:
        pulse_rate (float): _description_
    

    Daniel McDuff, Ethan Blackford, January 2019
    Copyright (c)
    Licensed under the MIT License and the RAIL AI License.
    """

    N = (60*FS)/FResBPM

    # Detrending + nth order butterworth + periodogram
    if DETREND:
        pleth_sig = custom_detrend(pleth_sig, 100)
    if BUTTER_ORDER:
        [b, a] = sig.butter(BUTTER_ORDER, [LL_PR/60, UL_PR/60], btype='bandpass', fs = FS)
    pleth_sig = sig.filtfilt(b, a, np.double(pleth_sig))
    
    # Calculate the PSD and the mask for the desired range
    if WELCH:
        F, Pxx = sig.welch(x=pleth_sig, nperseg=len(pleth_sig)//3, nfft=N, fs=FS)
    else:
        F, Pxx = sig.periodogram(x=pleth_sig,  nfft=N, fs=FS);  
    FMask = (F >= (LL_PR/60)) & (F <= (UL_PR/60))
    
    # Calculate predicted pulse rate:
    FRange = F * FMask
    PRange = Pxx * FMask

    if HARMONIC:
      harmonicsigPower = PRange[::2]
      harmonicsigPower = np.pad(harmonicsigPower, (0, len(PRange) - len(harmonicsigPower)))
      harmonicsigPower[0] = 0
      MaxInd = np.argmax(PRange+harmonicsigPower)
    else:
      MaxInd = np.argmax(PRange)
    pulse_rate_freq = FRange[MaxInd]
    pulse_rate = pulse_rate_freq*60
            
    return pulse_rate

# %%
class Args:
    # config_file = 'configs/train_configs/CogPhys_Resp_CONTRASTPHYS_BASIC.yaml'
    config_file = 'configs/train_configs/CogPhys_Resp_Waveform_BASIC.yaml'
    cached_path = None
    preprocess = None
    lr = None
    model_file_name = None

args = Args()
config = get_config(args)
# print('Configuration:')
# print(config, end='\n\n')
data_loader_dict = dict() # dictionary of data loaders 
train_loader = data_loader.CogPhysLoader.CogPhysLoader
print(config.DEVICE)
train_data_loader = train_loader(
    name="train",
    data_path=config.TRAIN.DATA.DATA_PATH,
    config_data=config.TRAIN.DATA,
    device=config.DEVICE)
data_loader_dict['train'] = DataLoader(
    dataset=train_data_loader,
    num_workers=2,
    batch_size=2,
    shuffle=True,
)
print(); print()

valid_loader = data_loader.CogPhysLoader.CogPhysLoader
print(config.DEVICE)
valid_data_loader = valid_loader(
    name="valid",
    data_path=config.VALID.DATA.DATA_PATH,
    config_data=config.VALID.DATA,
    device=config.DEVICE)
data_loader_dict['valid'] = DataLoader(
    dataset=valid_data_loader,
    num_workers=2,
    batch_size=2,
    shuffle=True,
)
print(); print()

test_loader = data_loader.CogPhysLoader.CogPhysLoader
print(config.DEVICE)
test_data_loader = test_loader(
    name="test",
    data_path=config.TEST.DATA.DATA_PATH,
    config_data=config.TEST.DATA,
    device=config.DEVICE)
data_loader_dict['test'] = DataLoader(
    dataset=test_data_loader,
    num_workers=4,
    batch_size=3,
    shuffle=False,
)
# Out:
# => Merging a config file from configs/train_configs/CogPhys_Resp_Waveform_BASIC.yaml
# cuda
# Cached Data Path /home/ab227/CogPhys/combined_respiratory_waveforms
#
# Data Path /home/ab227/CogPhys/combined_respiratory_waveforms
#
# train Preprocessed Dataset Length: 852
#
#
#
# cuda
# Cached Data Path /home/ab227/CogPhys/combined_respiratory_waveforms
#
# Data Path /home/ab227/CogPhys/combined_respiratory_waveforms
#
# valid Preprocessed Dataset Length: 66
#
#
#
# cuda
# Cached Data Path /home/ab227/CogPhys/combined_respiratory_waveforms
#
# Data Path /home/ab227/CogPhys/combined_respiratory_waveforms
#
# test Preprocessed Dataset Length: 342

# %%
valid_data_loader.input_preproc, valid_data_loader.label_preproc, valid_data_loader.input_keys, valid_data_loader.label_keys
# Out:
# ([['Standardize'], ['Standardize']],
#  [['Standardize']],
#  ['thermal_waveform', 'radar_waveform'],
#  ['gt_waveform'])

# %%
torch.cuda.empty_cache()

# %%
#all_epochs_load_path = '/home/ab227/CogPhys/runs/exp/resp_waveform_fusion1e-3_100/PreTrainedModels'
#CogPhys_rPPG_ch3_PhysNet_Epoch49.pth

def load_one_path(all_epochs_load_path, epoch_num):
    load_path = os.path.join(all_epochs_load_path, f'CogPhys_rPPG_ch3_PhysNet_Epoch{epoch_num}.pth') #change second part based on model used
    
    if config.MODEL.NAME == 'ContrastPhys':
        model = ContrastPhys(S=config.MODEL.CONTRASTPHYS.S).to(config.DEVICE).eval()
    elif config.MODEL.NAME == 'ContrastFusion':
        model = ContrastFusion(S=config.MODEL.CONTRASTFUSION.S).to(config.DEVICE).eval()
        model = torch.nn.DataParallel(model, device_ids=list(range(1)))
    elif config.MODEL.NAME == 'WaveformFusion':
        model = WaveformFusion(channels=config.MODEL.WAVEFORMFUSION.CHANNELS).to(config.DEVICE).eval()
    else:
        raise NotImplementedError(f"Model {config.MODEL.NAME} not implemented.")
    model.load_state_dict(torch.load(load_path, map_location=config.DEVICE), strict=True)
    
    return model

# %%
def forward_pass(model, img_data, gra_sharp=2.0):
    if config.MODEL.NAME == 'ContrastPhys':
        out = model(img_data)[0][-1].squeeze(0).cpu().numpy()
    elif config.MODEL.NAME == 'ContrastFusion':
        out = model(img_data)[0][-1].squeeze(0).cpu().numpy()
    elif config.MODEL.NAME == 'Physnet':
        out = model(img_data)[0].squeeze(0).cpu().numpy()
    elif config.MODEL.NAME == 'PhysMamba':
        out = model(img_data).squeeze(0).cpu().numpy()
    elif config.MODEL.NAME == 'FactorizePhys':
        out = model(img_data)[0].squeeze(0).cpu().numpy()
    elif config.MODEL.NAME == 'PhysFormer':
        out = model(img_data, gra_sharp)[0][-1].squeeze(0).cpu().numpy()
    elif config.MODEL.NAME == 'RhythmFormer':
        out = model(img_data).squeeze(0).cpu().numpy()
    elif config.MODEL.NAME == 'WaveformFusion':
        out = model(img_data)[0].squeeze(0).cpu().numpy()
    else:
        raise NotImplementedError(f"Model {config.MODEL.NAME} not implemented.")
    return out

# %%
def process_hr_ibi(
    all_pred,
    all_gt,
    all_participant_task_chunk_list,
    fs,
    ll_cutoff=8,
    ul_cutoff=30
):
    all_pred_hr = []
    all_gt_hr = []
    all_goodness = []

    for pred, gt, (participant_task, chunk_id_list) in zip(all_pred, all_gt, all_participant_task_chunk_list):
        #print(participant_task, chunk_id_list)

        # Normalize
        pred = (pred - np.mean(pred)) / np.std(pred)
        gt = (gt - np.mean(gt)) / np.std(gt)

        # Detrend and Goodness
        goodness = calcMetrics(pred, fs, 0.1, normalize=True)[1][0]

        # 1-D gauss blur
        # pred = custom_detrend(pred, 100)
        # gt = custom_detrend(gt, 100)
        pred = np.convolve(pred, np.ones((15)) / 15, mode='same')
        gt = np.convolve(gt, np.ones((15)) / 15, mode='same')

        # Re-normalize
        pred = (pred - np.mean(pred)) / np.std(pred)
        gt = (gt - np.mean(gt)) / np.std(gt)

        # Heart rate via PSD
        pred_hr = pulse_rate_from_power_spectral_density(pred, fs, ll_cutoff, ul_cutoff, BUTTER_ORDER=2, 
                                                        DETREND=True, WELCH=False)
        gt_hr = pulse_rate_from_power_spectral_density(gt, fs, ll_cutoff, ul_cutoff, BUTTER_ORDER=2, 
                                                        DETREND=True, WELCH=False)
    
        all_pred_hr.append(pred_hr)
        all_gt_hr.append(gt_hr)
        all_goodness.append(goodness)

        #print(f"| {pred_hr:.2f} - {gt_hr:.2f} | = {abs(pred_hr - gt_hr):.2f} bpm\t\t\t{goodness:.2f}")
        #print("-"*100)
        
    return (
        np.array(all_pred_hr),
        np.array(all_gt_hr),
        np.array(all_goodness)
    )
    
    
def get_error_metric(pred_values, gt_values):
    """
    Calculate the error metric between predicted and ground truth values.
    """
    # Calculate the mean absolute error
    mae = np.mean(np.abs(pred_values - gt_values))
    # Calculate the root mean squared error
    rmse = np.sqrt(np.mean(np.square(np.abs(pred_values - gt_values))))
    # Calculate the mean absolute percentage error
    mape = np.mean(np.abs((pred_values - gt_values) / gt_values)) * 100
    # Calculate pearson correlation coefficient
    r = np.corrcoef(pred_values, gt_values)[0, 1]
    return mae, rmse, mape, r


def evaluate_and_log_metrics(all_pred_hr, all_gt_hr, all_goodness, epoch_num, plot=False):

    all_errors = np.abs(all_pred_hr - all_gt_hr)

    # Error metrics
    mae, rmse, mape, r = get_error_metric(all_pred_hr, all_gt_hr)
    
    # Print LaTeX-style row
    print("MAE, RMSE, MAPE, r, IBI")
    print(np.round(mae,2), "&", np.round(rmse,2), "&", np.round(mape,2), "&", np.round(r,2), r"\\")

    # Plot results
    if plot:
        plt.figure(figsize=(20, 8))
        plt.subplot(1, 2, 1)
        plt.plot(all_pred_hr, all_gt_hr, 'o', alpha=0.5)
        plt.xlabel('Predicted HR')
        plt.ylabel('Ground Truth HR')
        plt.title(f'HR Prediction (Epoch {epoch_num})') 

        plt.subplot(1, 2, 2)
        plt.plot(all_goodness, all_errors, 'o', alpha=0.5)
        plt.xlabel('Goodness')
        plt.ylabel('Absolute HR Error')
        plt.title(f'Goodness vs HR Error (Epoch {epoch_num})')
        plt.show()

        plt.figure(figsize=(15, 5))
        plt.hist(np.array(all_pred_hr), bins=100, alpha=0.5, label='Predicted HR')
        plt.hist(np.array(all_gt_hr), bins=100, alpha=0.5, label='GT HR')
        plt.legend()
        plt.title(f'HR Distribution (Epoch {epoch_num})')
        plt.show()

    return np.array([mae, rmse, mape, r])

# %%
# FORWARD PASS CELL

metrics_table = []

all_epochs_load_path = '/home/ab227/CogPhys/runs/exp/resp_waveform_fusion1e-3_100/PreTrainedModels'
for i in range(0, len(os.listdir(all_epochs_load_path))):
    epoch_num = 5 * i - 1
    if epoch_num < 0:
        epoch_num = 0
    if epoch_num >= len(os.listdir(all_epochs_load_path)):
        break
    
    model = load_one_path(all_epochs_load_path, epoch_num)

    all_pred=[]
    all_gt = []
    all_participant_task_chunk_list = []
    for i in range(0, len(valid_data_loader), 6):
        for j in [[0, 1], [2, 3], [4, 5]]:
            img = []
            pred = []
            label = []
            participant_task_list = []
            chunk_id_list = []
            with torch.no_grad():
                for k in j:
                    img_sample, label_sample, participant_task, chunk_id = valid_data_loader[i+k]
                    participant_task_list.append(participant_task)
                    chunk_id_list.append(int(chunk_id))
                    img.append(img_sample.to(config.DEVICE))
                    label.extend(label_sample.squeeze(0).cpu().numpy().tolist())
                img = torch.cat(img, dim=1).unsqueeze(0)
                pred = forward_pass(model, img)
            ##################
            assert participant_task_list[0] == participant_task_list[1]
            assert chunk_id_list[0] == chunk_id_list[1]-1
            ##################
            pred = np.array(pred)
            label = np.array(label)
            all_participant_task_chunk_list.append((participant_task_list[0], chunk_id_list)) 
            all_pred.append(pred)
            all_gt.append(label)
            print(f'epoch{epoch_num}', participant_task_list[0], chunk_id_list)
            
    #now calc metrics for this model epoch path
    all_pred_hr, all_gt_hr, all_goodness = process_hr_ibi(all_pred, all_gt, all_participant_task_chunk_list, fs = config.TRAIN.DATA.FS)
    metrics = evaluate_and_log_metrics(all_pred_hr, all_gt_hr, all_goodness, epoch_num)
    print(metrics)
    metrics_table.append((epoch_num, metrics))
    
print(metrics_table)
# Out:
# epoch0 v33_number [0, 1]
# epoch0 v33_number [2, 3]
# epoch0 v33_number [4, 5]
# epoch0 v12_pattern [0, 1]
# epoch0 v12_pattern [2, 3]
# epoch0 v12_pattern [4, 5]
# epoch0 v33_still [0, 1]
# epoch0 v33_still [2, 3]
# epoch0 v33_still [4, 5]
# epoch0 v12_read [0, 1]
# epoch0 v12_read [2, 3]
# epoch0 v12_read [4, 5]
# epoch0 v33_read [0, 1]
# epoch0 v33_read [2, 3]
# epoch0 v33_read [4, 5]
# epoch0 v33_read_rest [0, 1]
# epoch0 v33_read_rest [2, 3]
# epoch0 v33_read_rest [4, 5]
# epoch0 v33_pattern_rest [0, 1]
# epoch0 v33_pattern_rest [2, 3]
# epoch0 v33_pattern_rest [4, 5]
# epoch0 v12_read_rest [0, 1]
# epoch0 v12_read_rest [2, 3]
# epoch0 v12_read_rest [4, 5]
# epoch0 v12_pattern_rest [0, 1]
# epoch0 v12_pattern_rest [2, 3]
# epoch0 v12_pattern_rest [4, 5]
# epoch0 v33_pattern [0, 1]
# epoch0 v33_pattern [2, 3]
# epoch0 v33_pattern [4, 5]
# epoch0 v12_number [0, 1]
# epoch0 v12_number [2, 3]
# epoch0 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.88 & 4.91 & 20.83 & 0.0 \\
# [3.87878788e+00 4.91158186e+00 2.08305187e+01 4.22244903e-03]
# epoch4 v33_number [0, 1]
# epoch4 v33_number [2, 3]
# epoch4 v33_number [4, 5]
# epoch4 v12_pattern [0, 1]
# epoch4 v12_pattern [2, 3]
# epoch4 v12_pattern [4, 5]
# epoch4 v33_still [0, 1]
# epoch4 v33_still [2, 3]
# epoch4 v33_still [4, 5]
# epoch4 v12_read [0, 1]
# epoch4 v12_read [2, 3]
# epoch4 v12_read [4, 5]
# epoch4 v33_read [0, 1]
# epoch4 v33_read [2, 3]
# epoch4 v33_read [4, 5]
# epoch4 v33_read_rest [0, 1]
# epoch4 v33_read_rest [2, 3]
# epoch4 v33_read_rest [4, 5]
# epoch4 v33_pattern_rest [0, 1]
# epoch4 v33_pattern_rest [2, 3]
# epoch4 v33_pattern_rest [4, 5]
# epoch4 v12_read_rest [0, 1]
# epoch4 v12_read_rest [2, 3]
# epoch4 v12_read_rest [4, 5]
# epoch4 v12_pattern_rest [0, 1]
# epoch4 v12_pattern_rest [2, 3]
# epoch4 v12_pattern_rest [4, 5]
# epoch4 v33_pattern [0, 1]
# epoch4 v33_pattern [2, 3]
# epoch4 v33_pattern [4, 5]
# epoch4 v12_number [0, 1]
# epoch4 v12_number [2, 3]
# epoch4 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.37 & 5.34 & 24.19 & -0.21 \\
# [ 4.36969697  5.33700631 24.19422352 -0.2053136 ]
# epoch9 v33_number [0, 1]
# epoch9 v33_number [2, 3]
# epoch9 v33_number [4, 5]
# epoch9 v12_pattern [0, 1]
# epoch9 v12_pattern [2, 3]
# epoch9 v12_pattern [4, 5]
# epoch9 v33_still [0, 1]
# epoch9 v33_still [2, 3]
# epoch9 v33_still [4, 5]
# epoch9 v12_read [0, 1]
# epoch9 v12_read [2, 3]
# epoch9 v12_read [4, 5]
# epoch9 v33_read [0, 1]
# epoch9 v33_read [2, 3]
# epoch9 v33_read [4, 5]
# epoch9 v33_read_rest [0, 1]
# epoch9 v33_read_rest [2, 3]
# epoch9 v33_read_rest [4, 5]
# epoch9 v33_pattern_rest [0, 1]
# epoch9 v33_pattern_rest [2, 3]
# epoch9 v33_pattern_rest [4, 5]
# epoch9 v12_read_rest [0, 1]
# epoch9 v12_read_rest [2, 3]
# epoch9 v12_read_rest [4, 5]
# epoch9 v12_pattern_rest [0, 1]
# epoch9 v12_pattern_rest [2, 3]
# epoch9 v12_pattern_rest [4, 5]
# epoch9 v33_pattern [0, 1]
# epoch9 v33_pattern [2, 3]
# epoch9 v33_pattern [4, 5]
# epoch9 v12_number [0, 1]
# epoch9 v12_number [2, 3]
# epoch9 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.79 & 5.01 & 21.47 & 0.03 \\
# [ 3.79393939  5.0144035  21.47235167  0.03033377]
# epoch14 v33_number [0, 1]
# epoch14 v33_number [2, 3]
# epoch14 v33_number [4, 5]
# epoch14 v12_pattern [0, 1]
# epoch14 v12_pattern [2, 3]
# epoch14 v12_pattern [4, 5]
# epoch14 v33_still [0, 1]
# epoch14 v33_still [2, 3]
# epoch14 v33_still [4, 5]
# epoch14 v12_read [0, 1]
# epoch14 v12_read [2, 3]
# epoch14 v12_read [4, 5]
# epoch14 v33_read [0, 1]
# epoch14 v33_read [2, 3]
# epoch14 v33_read [4, 5]
# epoch14 v33_read_rest [0, 1]
# epoch14 v33_read_rest [2, 3]
# epoch14 v33_read_rest [4, 5]
# epoch14 v33_pattern_rest [0, 1]
# epoch14 v33_pattern_rest [2, 3]
# epoch14 v33_pattern_rest [4, 5]
# epoch14 v12_read_rest [0, 1]
# epoch14 v12_read_rest [2, 3]
# epoch14 v12_read_rest [4, 5]
# epoch14 v12_pattern_rest [0, 1]
# epoch14 v12_pattern_rest [2, 3]
# epoch14 v12_pattern_rest [4, 5]
# epoch14 v33_pattern [0, 1]
# epoch14 v33_pattern [2, 3]
# epoch14 v33_pattern [4, 5]
# epoch14 v12_number [0, 1]
# epoch14 v12_number [2, 3]
# epoch14 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.47 & 4.56 & 19.23 & 0.06 \\
# [ 3.47272727  4.56276099 19.23046452  0.06094546]
# epoch19 v33_number [0, 1]
# epoch19 v33_number [2, 3]
# epoch19 v33_number [4, 5]
# epoch19 v12_pattern [0, 1]
# epoch19 v12_pattern [2, 3]
# epoch19 v12_pattern [4, 5]
# epoch19 v33_still [0, 1]
# epoch19 v33_still [2, 3]
# epoch19 v33_still [4, 5]
# epoch19 v12_read [0, 1]
# epoch19 v12_read [2, 3]
# epoch19 v12_read [4, 5]
# epoch19 v33_read [0, 1]
# epoch19 v33_read [2, 3]
# epoch19 v33_read [4, 5]
# epoch19 v33_read_rest [0, 1]
# epoch19 v33_read_rest [2, 3]
# epoch19 v33_read_rest [4, 5]
# epoch19 v33_pattern_rest [0, 1]
# epoch19 v33_pattern_rest [2, 3]
# epoch19 v33_pattern_rest [4, 5]
# epoch19 v12_read_rest [0, 1]
# epoch19 v12_read_rest [2, 3]
# epoch19 v12_read_rest [4, 5]
# epoch19 v12_pattern_rest [0, 1]
# epoch19 v12_pattern_rest [2, 3]
# epoch19 v12_pattern_rest [4, 5]
# epoch19 v33_pattern [0, 1]
# epoch19 v33_pattern [2, 3]
# epoch19 v33_pattern [4, 5]
# epoch19 v12_number [0, 1]
# epoch19 v12_number [2, 3]
# epoch19 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.79 & 4.96 & 20.02 & 0.26 \\
# [ 3.78787879  4.96478508 20.01853507  0.25747115]
# epoch24 v33_number [0, 1]
# epoch24 v33_number [2, 3]
# epoch24 v33_number [4, 5]
# epoch24 v12_pattern [0, 1]
# epoch24 v12_pattern [2, 3]
# epoch24 v12_pattern [4, 5]
# epoch24 v33_still [0, 1]
# epoch24 v33_still [2, 3]
# epoch24 v33_still [4, 5]
# epoch24 v12_read [0, 1]
# epoch24 v12_read [2, 3]
# epoch24 v12_read [4, 5]
# epoch24 v33_read [0, 1]
# epoch24 v33_read [2, 3]
# epoch24 v33_read [4, 5]
# epoch24 v33_read_rest [0, 1]
# epoch24 v33_read_rest [2, 3]
# epoch24 v33_read_rest [4, 5]
# epoch24 v33_pattern_rest [0, 1]
# epoch24 v33_pattern_rest [2, 3]
# epoch24 v33_pattern_rest [4, 5]
# epoch24 v12_read_rest [0, 1]
# epoch24 v12_read_rest [2, 3]
# epoch24 v12_read_rest [4, 5]
# epoch24 v12_pattern_rest [0, 1]
# epoch24 v12_pattern_rest [2, 3]
# epoch24 v12_pattern_rest [4, 5]
# epoch24 v33_pattern [0, 1]
# epoch24 v33_pattern [2, 3]
# epoch24 v33_pattern [4, 5]
# epoch24 v12_number [0, 1]
# epoch24 v12_number [2, 3]
# epoch24 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.75 & 4.9 & 19.98 & 0.27 \\
# [ 3.75454545  4.90154583 19.97885851  0.26769168]
# epoch29 v33_number [0, 1]
# epoch29 v33_number [2, 3]
# epoch29 v33_number [4, 5]
# epoch29 v12_pattern [0, 1]
# epoch29 v12_pattern [2, 3]
# epoch29 v12_pattern [4, 5]
# epoch29 v33_still [0, 1]
# epoch29 v33_still [2, 3]
# epoch29 v33_still [4, 5]
# epoch29 v12_read [0, 1]
# epoch29 v12_read [2, 3]
# epoch29 v12_read [4, 5]
# epoch29 v33_read [0, 1]
# epoch29 v33_read [2, 3]
# epoch29 v33_read [4, 5]
# epoch29 v33_read_rest [0, 1]
# epoch29 v33_read_rest [2, 3]
# epoch29 v33_read_rest [4, 5]
# epoch29 v33_pattern_rest [0, 1]
# epoch29 v33_pattern_rest [2, 3]
# epoch29 v33_pattern_rest [4, 5]
# epoch29 v12_read_rest [0, 1]
# epoch29 v12_read_rest [2, 3]
# epoch29 v12_read_rest [4, 5]
# epoch29 v12_pattern_rest [0, 1]
# epoch29 v12_pattern_rest [2, 3]
# epoch29 v12_pattern_rest [4, 5]
# epoch29 v33_pattern [0, 1]
# epoch29 v33_pattern [2, 3]
# epoch29 v33_pattern [4, 5]
# epoch29 v12_number [0, 1]
# epoch29 v12_number [2, 3]
# epoch29 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.37 & 5.5 & 22.74 & 0.21 \\
# [ 4.36666667  5.4993388  22.73751831  0.20940384]
# epoch34 v33_number [0, 1]
# epoch34 v33_number [2, 3]
# epoch34 v33_number [4, 5]
# epoch34 v12_pattern [0, 1]
# epoch34 v12_pattern [2, 3]
# epoch34 v12_pattern [4, 5]
# epoch34 v33_still [0, 1]
# epoch34 v33_still [2, 3]
# epoch34 v33_still [4, 5]
# epoch34 v12_read [0, 1]
# epoch34 v12_read [2, 3]
# epoch34 v12_read [4, 5]
# epoch34 v33_read [0, 1]
# epoch34 v33_read [2, 3]
# epoch34 v33_read [4, 5]
# epoch34 v33_read_rest [0, 1]
# epoch34 v33_read_rest [2, 3]
# epoch34 v33_read_rest [4, 5]
# epoch34 v33_pattern_rest [0, 1]
# epoch34 v33_pattern_rest [2, 3]
# epoch34 v33_pattern_rest [4, 5]
# epoch34 v12_read_rest [0, 1]
# epoch34 v12_read_rest [2, 3]
# epoch34 v12_read_rest [4, 5]
# epoch34 v12_pattern_rest [0, 1]
# epoch34 v12_pattern_rest [2, 3]
# epoch34 v12_pattern_rest [4, 5]
# epoch34 v33_pattern [0, 1]
# epoch34 v33_pattern [2, 3]
# epoch34 v33_pattern [4, 5]
# epoch34 v12_number [0, 1]
# epoch34 v12_number [2, 3]
# epoch34 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.12 & 5.17 & 21.62 & 0.25 \\
# [ 4.11515152  5.1721281  21.61550841  0.25312328]
# epoch39 v33_number [0, 1]
# epoch39 v33_number [2, 3]
# epoch39 v33_number [4, 5]
# epoch39 v12_pattern [0, 1]
# epoch39 v12_pattern [2, 3]
# epoch39 v12_pattern [4, 5]
# epoch39 v33_still [0, 1]
# epoch39 v33_still [2, 3]
# epoch39 v33_still [4, 5]
# epoch39 v12_read [0, 1]
# epoch39 v12_read [2, 3]
# epoch39 v12_read [4, 5]
# epoch39 v33_read [0, 1]
# epoch39 v33_read [2, 3]
# epoch39 v33_read [4, 5]
# epoch39 v33_read_rest [0, 1]
# epoch39 v33_read_rest [2, 3]
# epoch39 v33_read_rest [4, 5]
# epoch39 v33_pattern_rest [0, 1]
# epoch39 v33_pattern_rest [2, 3]
# epoch39 v33_pattern_rest [4, 5]
# epoch39 v12_read_rest [0, 1]
# epoch39 v12_read_rest [2, 3]
# epoch39 v12_read_rest [4, 5]
# epoch39 v12_pattern_rest [0, 1]
# epoch39 v12_pattern_rest [2, 3]
# epoch39 v12_pattern_rest [4, 5]
# epoch39 v33_pattern [0, 1]
# epoch39 v33_pattern [2, 3]
# epoch39 v33_pattern [4, 5]
# epoch39 v12_number [0, 1]
# epoch39 v12_number [2, 3]
# epoch39 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.54 & 4.64 & 19.09 & 0.35 \\
# [ 3.53636364  4.63625371 19.09499205  0.34852372]
# epoch44 v33_number [0, 1]
# epoch44 v33_number [2, 3]
# epoch44 v33_number [4, 5]
# epoch44 v12_pattern [0, 1]
# epoch44 v12_pattern [2, 3]
# epoch44 v12_pattern [4, 5]
# epoch44 v33_still [0, 1]
# epoch44 v33_still [2, 3]
# epoch44 v33_still [4, 5]
# epoch44 v12_read [0, 1]
# epoch44 v12_read [2, 3]
# epoch44 v12_read [4, 5]
# epoch44 v33_read [0, 1]
# epoch44 v33_read [2, 3]
# epoch44 v33_read [4, 5]
# epoch44 v33_read_rest [0, 1]
# epoch44 v33_read_rest [2, 3]
# epoch44 v33_read_rest [4, 5]
# epoch44 v33_pattern_rest [0, 1]
# epoch44 v33_pattern_rest [2, 3]
# epoch44 v33_pattern_rest [4, 5]
# epoch44 v12_read_rest [0, 1]
# epoch44 v12_read_rest [2, 3]
# epoch44 v12_read_rest [4, 5]
# epoch44 v12_pattern_rest [0, 1]
# epoch44 v12_pattern_rest [2, 3]
# epoch44 v12_pattern_rest [4, 5]
# epoch44 v33_pattern [0, 1]
# epoch44 v33_pattern [2, 3]
# epoch44 v33_pattern [4, 5]
# epoch44 v12_number [0, 1]
# epoch44 v12_number [2, 3]
# epoch44 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.14 & 5.08 & 22.08 & 0.25 \\
# [ 4.14242424  5.07581909 22.0762718   0.24846358]
# epoch49 v33_number [0, 1]
# epoch49 v33_number [2, 3]
# epoch49 v33_number [4, 5]
# epoch49 v12_pattern [0, 1]
# epoch49 v12_pattern [2, 3]
# epoch49 v12_pattern [4, 5]
# epoch49 v33_still [0, 1]
# epoch49 v33_still [2, 3]
# epoch49 v33_still [4, 5]
# epoch49 v12_read [0, 1]
# epoch49 v12_read [2, 3]
# epoch49 v12_read [4, 5]
# epoch49 v33_read [0, 1]
# epoch49 v33_read [2, 3]
# epoch49 v33_read [4, 5]
# epoch49 v33_read_rest [0, 1]
# epoch49 v33_read_rest [2, 3]
# epoch49 v33_read_rest [4, 5]
# epoch49 v33_pattern_rest [0, 1]
# epoch49 v33_pattern_rest [2, 3]
# epoch49 v33_pattern_rest [4, 5]
# epoch49 v12_read_rest [0, 1]
# epoch49 v12_read_rest [2, 3]
# epoch49 v12_read_rest [4, 5]
# epoch49 v12_pattern_rest [0, 1]
# epoch49 v12_pattern_rest [2, 3]
# epoch49 v12_pattern_rest [4, 5]
# epoch49 v33_pattern [0, 1]
# epoch49 v33_pattern [2, 3]
# epoch49 v33_pattern [4, 5]
# epoch49 v12_number [0, 1]
# epoch49 v12_number [2, 3]
# epoch49 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.55 & 4.81 & 19.85 & 0.09 \\
# [ 3.54848485  4.80923984 19.84545171  0.08757607]
# epoch54 v33_number [0, 1]
# epoch54 v33_number [2, 3]
# epoch54 v33_number [4, 5]
# epoch54 v12_pattern [0, 1]
# epoch54 v12_pattern [2, 3]
# epoch54 v12_pattern [4, 5]
# epoch54 v33_still [0, 1]
# epoch54 v33_still [2, 3]
# epoch54 v33_still [4, 5]
# epoch54 v12_read [0, 1]
# epoch54 v12_read [2, 3]
# epoch54 v12_read [4, 5]
# epoch54 v33_read [0, 1]
# epoch54 v33_read [2, 3]
# epoch54 v33_read [4, 5]
# epoch54 v33_read_rest [0, 1]
# epoch54 v33_read_rest [2, 3]
# epoch54 v33_read_rest [4, 5]
# epoch54 v33_pattern_rest [0, 1]
# epoch54 v33_pattern_rest [2, 3]
# epoch54 v33_pattern_rest [4, 5]
# epoch54 v12_read_rest [0, 1]
# epoch54 v12_read_rest [2, 3]
# epoch54 v12_read_rest [4, 5]
# epoch54 v12_pattern_rest [0, 1]
# epoch54 v12_pattern_rest [2, 3]
# epoch54 v12_pattern_rest [4, 5]
# epoch54 v33_pattern [0, 1]
# epoch54 v33_pattern [2, 3]
# epoch54 v33_pattern [4, 5]
# epoch54 v12_number [0, 1]
# epoch54 v12_number [2, 3]
# epoch54 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.56 & 4.7 & 20.13 & 0.17 \\
# [ 3.56363636  4.69713001 20.13347755  0.1688996 ]
# epoch59 v33_number [0, 1]
# epoch59 v33_number [2, 3]
# epoch59 v33_number [4, 5]
# epoch59 v12_pattern [0, 1]
# epoch59 v12_pattern [2, 3]
# epoch59 v12_pattern [4, 5]
# epoch59 v33_still [0, 1]
# epoch59 v33_still [2, 3]
# epoch59 v33_still [4, 5]
# epoch59 v12_read [0, 1]
# epoch59 v12_read [2, 3]
# epoch59 v12_read [4, 5]
# epoch59 v33_read [0, 1]
# epoch59 v33_read [2, 3]
# epoch59 v33_read [4, 5]
# epoch59 v33_read_rest [0, 1]
# epoch59 v33_read_rest [2, 3]
# epoch59 v33_read_rest [4, 5]
# epoch59 v33_pattern_rest [0, 1]
# epoch59 v33_pattern_rest [2, 3]
# epoch59 v33_pattern_rest [4, 5]
# epoch59 v12_read_rest [0, 1]
# epoch59 v12_read_rest [2, 3]
# epoch59 v12_read_rest [4, 5]
# epoch59 v12_pattern_rest [0, 1]
# epoch59 v12_pattern_rest [2, 3]
# epoch59 v12_pattern_rest [4, 5]
# epoch59 v33_pattern [0, 1]
# epoch59 v33_pattern [2, 3]
# epoch59 v33_pattern [4, 5]
# epoch59 v12_number [0, 1]
# epoch59 v12_number [2, 3]
# epoch59 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.0 & 5.0 & 21.64 & 0.2 \\
# [ 4.          4.99648361 21.64067848  0.19542166]
# epoch64 v33_number [0, 1]
# epoch64 v33_number [2, 3]
# epoch64 v33_number [4, 5]
# epoch64 v12_pattern [0, 1]
# epoch64 v12_pattern [2, 3]
# epoch64 v12_pattern [4, 5]
# epoch64 v33_still [0, 1]
# epoch64 v33_still [2, 3]
# epoch64 v33_still [4, 5]
# epoch64 v12_read [0, 1]
# epoch64 v12_read [2, 3]
# epoch64 v12_read [4, 5]
# epoch64 v33_read [0, 1]
# epoch64 v33_read [2, 3]
# epoch64 v33_read [4, 5]
# epoch64 v33_read_rest [0, 1]
# epoch64 v33_read_rest [2, 3]
# epoch64 v33_read_rest [4, 5]
# epoch64 v33_pattern_rest [0, 1]
# epoch64 v33_pattern_rest [2, 3]
# epoch64 v33_pattern_rest [4, 5]
# epoch64 v12_read_rest [0, 1]
# epoch64 v12_read_rest [2, 3]
# epoch64 v12_read_rest [4, 5]
# epoch64 v12_pattern_rest [0, 1]
# epoch64 v12_pattern_rest [2, 3]
# epoch64 v12_pattern_rest [4, 5]
# epoch64 v33_pattern [0, 1]
# epoch64 v33_pattern [2, 3]
# epoch64 v33_pattern [4, 5]
# epoch64 v12_number [0, 1]
# epoch64 v12_number [2, 3]
# epoch64 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.03 & 4.98 & 21.34 & 0.23 \\
# [ 4.02727273  4.98266693 21.33581589  0.2277203 ]
# epoch69 v33_number [0, 1]
# epoch69 v33_number [2, 3]
# epoch69 v33_number [4, 5]
# epoch69 v12_pattern [0, 1]
# epoch69 v12_pattern [2, 3]
# epoch69 v12_pattern [4, 5]
# epoch69 v33_still [0, 1]
# epoch69 v33_still [2, 3]
# epoch69 v33_still [4, 5]
# epoch69 v12_read [0, 1]
# epoch69 v12_read [2, 3]
# epoch69 v12_read [4, 5]
# epoch69 v33_read [0, 1]
# epoch69 v33_read [2, 3]
# epoch69 v33_read [4, 5]
# epoch69 v33_read_rest [0, 1]
# epoch69 v33_read_rest [2, 3]
# epoch69 v33_read_rest [4, 5]
# epoch69 v33_pattern_rest [0, 1]
# epoch69 v33_pattern_rest [2, 3]
# epoch69 v33_pattern_rest [4, 5]
# epoch69 v12_read_rest [0, 1]
# epoch69 v12_read_rest [2, 3]
# epoch69 v12_read_rest [4, 5]
# epoch69 v12_pattern_rest [0, 1]
# epoch69 v12_pattern_rest [2, 3]
# epoch69 v12_pattern_rest [4, 5]
# epoch69 v33_pattern [0, 1]
# epoch69 v33_pattern [2, 3]
# epoch69 v33_pattern [4, 5]
# epoch69 v12_number [0, 1]
# epoch69 v12_number [2, 3]
# epoch69 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.77 & 4.84 & 19.71 & 0.32 \\
# [ 3.77272727  4.84458461 19.71291966  0.32265669]
# epoch74 v33_number [0, 1]
# epoch74 v33_number [2, 3]
# epoch74 v33_number [4, 5]
# epoch74 v12_pattern [0, 1]
# epoch74 v12_pattern [2, 3]
# epoch74 v12_pattern [4, 5]
# epoch74 v33_still [0, 1]
# epoch74 v33_still [2, 3]
# epoch74 v33_still [4, 5]
# epoch74 v12_read [0, 1]
# epoch74 v12_read [2, 3]
# epoch74 v12_read [4, 5]
# epoch74 v33_read [0, 1]
# epoch74 v33_read [2, 3]
# epoch74 v33_read [4, 5]
# epoch74 v33_read_rest [0, 1]
# epoch74 v33_read_rest [2, 3]
# epoch74 v33_read_rest [4, 5]
# epoch74 v33_pattern_rest [0, 1]
# epoch74 v33_pattern_rest [2, 3]
# epoch74 v33_pattern_rest [4, 5]
# epoch74 v12_read_rest [0, 1]
# epoch74 v12_read_rest [2, 3]
# epoch74 v12_read_rest [4, 5]
# epoch74 v12_pattern_rest [0, 1]
# epoch74 v12_pattern_rest [2, 3]
# epoch74 v12_pattern_rest [4, 5]
# epoch74 v33_pattern [0, 1]
# epoch74 v33_pattern [2, 3]
# epoch74 v33_pattern [4, 5]
# epoch74 v12_number [0, 1]
# epoch74 v12_number [2, 3]
# epoch74 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.22 & 5.26 & 22.18 & 0.25 \\
# [ 4.21515152  5.26132257 22.17518314  0.24674586]
# epoch79 v33_number [0, 1]
# epoch79 v33_number [2, 3]
# epoch79 v33_number [4, 5]
# epoch79 v12_pattern [0, 1]
# epoch79 v12_pattern [2, 3]
# epoch79 v12_pattern [4, 5]
# epoch79 v33_still [0, 1]
# epoch79 v33_still [2, 3]
# epoch79 v33_still [4, 5]
# epoch79 v12_read [0, 1]
# epoch79 v12_read [2, 3]
# epoch79 v12_read [4, 5]
# epoch79 v33_read [0, 1]
# epoch79 v33_read [2, 3]
# epoch79 v33_read [4, 5]
# epoch79 v33_read_rest [0, 1]
# epoch79 v33_read_rest [2, 3]
# epoch79 v33_read_rest [4, 5]
# epoch79 v33_pattern_rest [0, 1]
# epoch79 v33_pattern_rest [2, 3]
# epoch79 v33_pattern_rest [4, 5]
# epoch79 v12_read_rest [0, 1]
# epoch79 v12_read_rest [2, 3]
# epoch79 v12_read_rest [4, 5]
# epoch79 v12_pattern_rest [0, 1]
# epoch79 v12_pattern_rest [2, 3]
# epoch79 v12_pattern_rest [4, 5]
# epoch79 v33_pattern [0, 1]
# epoch79 v33_pattern [2, 3]
# epoch79 v33_pattern [4, 5]
# epoch79 v12_number [0, 1]
# epoch79 v12_number [2, 3]
# epoch79 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.03 & 5.06 & 21.03 & 0.3 \\
# [ 4.03030303  5.05778728 21.02599372  0.30043978]
# epoch84 v33_number [0, 1]
# epoch84 v33_number [2, 3]
# epoch84 v33_number [4, 5]
# epoch84 v12_pattern [0, 1]
# epoch84 v12_pattern [2, 3]
# epoch84 v12_pattern [4, 5]
# epoch84 v33_still [0, 1]
# epoch84 v33_still [2, 3]
# epoch84 v33_still [4, 5]
# epoch84 v12_read [0, 1]
# epoch84 v12_read [2, 3]
# epoch84 v12_read [4, 5]
# epoch84 v33_read [0, 1]
# epoch84 v33_read [2, 3]
# epoch84 v33_read [4, 5]
# epoch84 v33_read_rest [0, 1]
# epoch84 v33_read_rest [2, 3]
# epoch84 v33_read_rest [4, 5]
# epoch84 v33_pattern_rest [0, 1]
# epoch84 v33_pattern_rest [2, 3]
# epoch84 v33_pattern_rest [4, 5]
# epoch84 v12_read_rest [0, 1]
# epoch84 v12_read_rest [2, 3]
# epoch84 v12_read_rest [4, 5]
# epoch84 v12_pattern_rest [0, 1]
# epoch84 v12_pattern_rest [2, 3]
# epoch84 v12_pattern_rest [4, 5]
# epoch84 v33_pattern [0, 1]
# epoch84 v33_pattern [2, 3]
# epoch84 v33_pattern [4, 5]
# epoch84 v12_number [0, 1]
# epoch84 v12_number [2, 3]
# epoch84 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.09 & 5.08 & 21.77 & 0.3 \\
# [ 4.09090909  5.08038414 21.77148168  0.29665225]
# epoch89 v33_number [0, 1]
# epoch89 v33_number [2, 3]
# epoch89 v33_number [4, 5]
# epoch89 v12_pattern [0, 1]
# epoch89 v12_pattern [2, 3]
# epoch89 v12_pattern [4, 5]
# epoch89 v33_still [0, 1]
# epoch89 v33_still [2, 3]
# epoch89 v33_still [4, 5]
# epoch89 v12_read [0, 1]
# epoch89 v12_read [2, 3]
# epoch89 v12_read [4, 5]
# epoch89 v33_read [0, 1]
# epoch89 v33_read [2, 3]
# epoch89 v33_read [4, 5]
# epoch89 v33_read_rest [0, 1]
# epoch89 v33_read_rest [2, 3]
# epoch89 v33_read_rest [4, 5]
# epoch89 v33_pattern_rest [0, 1]
# epoch89 v33_pattern_rest [2, 3]
# epoch89 v33_pattern_rest [4, 5]
# epoch89 v12_read_rest [0, 1]
# epoch89 v12_read_rest [2, 3]
# epoch89 v12_read_rest [4, 5]
# epoch89 v12_pattern_rest [0, 1]
# epoch89 v12_pattern_rest [2, 3]
# epoch89 v12_pattern_rest [4, 5]
# epoch89 v33_pattern [0, 1]
# epoch89 v33_pattern [2, 3]
# epoch89 v33_pattern [4, 5]
# epoch89 v12_number [0, 1]
# epoch89 v12_number [2, 3]
# epoch89 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 4.12 & 5.19 & 21.74 & 0.23 \\
# [ 4.12424242  5.19081356 21.73961885  0.22949077]
# epoch94 v33_number [0, 1]
# epoch94 v33_number [2, 3]
# epoch94 v33_number [4, 5]
# epoch94 v12_pattern [0, 1]
# epoch94 v12_pattern [2, 3]
# epoch94 v12_pattern [4, 5]
# epoch94 v33_still [0, 1]
# epoch94 v33_still [2, 3]
# epoch94 v33_still [4, 5]
# epoch94 v12_read [0, 1]
# epoch94 v12_read [2, 3]
# epoch94 v12_read [4, 5]
# epoch94 v33_read [0, 1]
# epoch94 v33_read [2, 3]
# epoch94 v33_read [4, 5]
# epoch94 v33_read_rest [0, 1]
# epoch94 v33_read_rest [2, 3]
# epoch94 v33_read_rest [4, 5]
# epoch94 v33_pattern_rest [0, 1]
# epoch94 v33_pattern_rest [2, 3]
# epoch94 v33_pattern_rest [4, 5]
# epoch94 v12_read_rest [0, 1]
# epoch94 v12_read_rest [2, 3]
# epoch94 v12_read_rest [4, 5]
# epoch94 v12_pattern_rest [0, 1]
# epoch94 v12_pattern_rest [2, 3]
# epoch94 v12_pattern_rest [4, 5]
# epoch94 v33_pattern [0, 1]
# epoch94 v33_pattern [2, 3]
# epoch94 v33_pattern [4, 5]
# epoch94 v12_number [0, 1]
# epoch94 v12_number [2, 3]
# epoch94 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.99 & 5.07 & 21.12 & 0.29 \\
# [ 3.99393939  5.06820152 21.12373277  0.29255301]
# epoch99 v33_number [0, 1]
# epoch99 v33_number [2, 3]
# epoch99 v33_number [4, 5]
# epoch99 v12_pattern [0, 1]
# epoch99 v12_pattern [2, 3]
# epoch99 v12_pattern [4, 5]
# epoch99 v33_still [0, 1]
# epoch99 v33_still [2, 3]
# epoch99 v33_still [4, 5]
# epoch99 v12_read [0, 1]
# epoch99 v12_read [2, 3]
# epoch99 v12_read [4, 5]
# epoch99 v33_read [0, 1]
# epoch99 v33_read [2, 3]
# epoch99 v33_read [4, 5]
# epoch99 v33_read_rest [0, 1]
# epoch99 v33_read_rest [2, 3]
# epoch99 v33_read_rest [4, 5]
# epoch99 v33_pattern_rest [0, 1]
# epoch99 v33_pattern_rest [2, 3]
# epoch99 v33_pattern_rest [4, 5]
# epoch99 v12_read_rest [0, 1]
# epoch99 v12_read_rest [2, 3]
# epoch99 v12_read_rest [4, 5]
# epoch99 v12_pattern_rest [0, 1]
# epoch99 v12_pattern_rest [2, 3]
# epoch99 v12_pattern_rest [4, 5]
# epoch99 v33_pattern [0, 1]
# epoch99 v33_pattern [2, 3]
# epoch99 v33_pattern [4, 5]
# epoch99 v12_number [0, 1]
# epoch99 v12_number [2, 3]
# epoch99 v12_number [4, 5]
# MAE, RMSE, MAPE, r, IBI
# 3.96 & 5.04 & 20.68 & 0.31 \\
# [ 3.96060606  5.03896935 20.6799957   0.31023244]
# [(0, array([3.87878788e+00, 4.91158186e+00, 2.08305187e+01, 4.22244903e-03])), (4, array([ 4.36969697,  5.33700631, 24.19422352, -0.2053136 ])), (9, array([ 3.79393939,  5.0144035 , 21.47235167,  0.03033377])), (14, array([ 3.47272727,  4.56276099, 19.23046452,  0.06094546])), (19, array([ 3.78787879,  4.96478508, 20.01853507,  0.25747115])), (24, array([ 3.75454545,  4.90154583, 19.97885851,  0.26769168])), (29, array([ 4.36666667,  5.4993388 , 22.73751831,  0.20940384])), (34, array([ 4.11515152,  5.1721281 , 21.61550841,  0.25312328])), (39, array([ 3.53636364,  4.63625371, 19.09499205,  0.34852372])), (44, array([ 4.14242424,  5.07581909, 22.0762718 ,  0.24846358])), (49, array([ 3.54848485,  4.80923984, 19.84545171,  0.08757607])), (54, array([ 3.56363636,  4.69713001, 20.13347755,  0.1688996 ])), (59, array([ 4.        ,  4.99648361, 21.64067848,  0.19542166])), (64, array([ 4.02727273,  4.98266693, 21.33581589,  0.2277203 ])), (69, array([ 3.77272727,  4.84458461, 19.71291966,  0.32265669])), (74, array([ 4.21515152,  5.26132257, 22.17518314,  0.24674586])), (79, array([ 4.03030303,  5.05778728, 21.02599372,  0.30043978])), (84, array([ 4.09090909,  5.08038414, 21.77148168,  0.29665225])), (89, array([ 4.12424242,  5.19081356, 21.73961885,  0.22949077])), (94, array([ 3.99393939,  5.06820152, 21.12373277,  0.29255301])), (99, array([ 3.96060606,  5.03896935, 20.6799957 ,  0.31023244]))]

# %%
import pandas as pd

np.save('val_epoch_compare/resp_wave_fusion_val.npy', np.stack([row[1] for row in metrics_table]))

# Convert to DataFrame
df = pd.DataFrame(metrics_table, columns=["Epoch", "Metrics"])
df[['MAE', 'RMSE', 'MAPE', 'r']] = pd.DataFrame(df["Metrics"].tolist(), index=df.index)
df = df.drop(columns="Metrics")

# Optional: format float display
pd.options.display.float_format = '{:.4f}'.format

# Show the formatted table
print(df.to_string(index=False))
# Out:
#  Epoch    MAE   RMSE    MAPE       r
#      0 3.8788 4.9116 20.8305  0.0042
#      4 4.3697 5.3370 24.1942 -0.2053
#      9 3.7939 5.0144 21.4724  0.0303
#     14 3.4727 4.5628 19.2305  0.0609
#     19 3.7879 4.9648 20.0185  0.2575
#     24 3.7545 4.9015 19.9789  0.2677
#     29 4.3667 5.4993 22.7375  0.2094
#     34 4.1152 5.1721 21.6155  0.2531
#     39 3.5364 4.6363 19.0950  0.3485
#     44 4.1424 5.0758 22.0763  0.2485
#     49 3.5485 4.8092 19.8455  0.0876
#     54 3.5636 4.6971 20.1335  0.1689
#     59 4.0000 4.9965 21.6407  0.1954
#     64 4.0273 4.9827 21.3358  0.2277
#     69 3.7727 4.8446 19.7129  0.3227
#     74 4.2152 5.2613 22.1752  0.2467
#     79 4.0303 5.0578 21.0260  0.3004
#     84 4.0909 5.0804 21.7715  0.2967
#     89 4.1242 5.1908 21.7396  0.2295
#     94 3.9939 5.0682 21.1237  0.2926
#     99 3.9606 5.0390 20.6800  0.3102

# %%
# print(len(all_pred), len(all_gt), len(all_participant_task_chunk_list))
# save_folder = "waveforms/resp/wave_fusion"
# os.makedirs(save_folder, exist_ok=True)
# with open(os.path.join(save_folder, "pred.pickle"), 'wb') as f:
#     pickle.dump({'pred': all_pred, 'gt': all_gt, 'participant_task_chunk_id_list': all_participant_task_chunk_list}, f)
# with open(os.path.join(save_folder, "pred.pickle"), 'rb') as f:
#     data = pickle.load(f)
#     pred = data['pred']
#     gt = data['gt']
#     participant_task_chunk_id_list = data['participant_task_chunk_id_list']
# print(len(pred), len(gt), len(participant_task_chunk_id_list))
